# %%
from PIL import Image

# %%
pil= Image.open('thor.jpg')

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=212x237 at 0x2AE242B6DA0>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
arr = np.array(pil)

# %% [markdown]
# ## it will be like (r,g,b)     image is three dimensional

# %%
arr.shape
# Out:
# (237, 212, 3)

# %%
arr.shape
# Out:
# (237, 212, 3)

# %%
cut = arr[:100,:100]

# %%
plt.imshow(cut)
