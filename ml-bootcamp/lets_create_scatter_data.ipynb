# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(2,20,1000)

# %%
m,c = 3,10

# %%
y = m*x +c

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
noise = np.random.randn(1000) * 5

# %%
y_mod = y + noise

# %%
plt.scatter(x,y_mod)

# %%
x=np.random.randn(10000)

# %%
x
# Out:
# array([-1.05193766, -1.06776721, -0.53882823, ..., -1.56451878,
#        -0.92043533, -0.94242194])

# %%
out=plt.hist(x,bins=130)

# %%
p = x=np.random.randint(-10,10,10000)

# %%
out1=plt.hist(p,bins=120)

# %%
plt.pie([10,20,30])
# Out:
# ([<matplotlib.patches.Wedge at 0x232662703c8>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.5500000594609755, 0.9526279098330699, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
x = plt.pie(np.linspace(2,20,1000))

# %%
out=plt.pie([10,20,30],explode=[0,.9,0] ,shadow=True,radius=3)
