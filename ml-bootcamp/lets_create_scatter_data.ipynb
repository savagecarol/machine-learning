# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(2,20,100)

# %%
m,c = 3,10

# %%
y = m*x +c

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
noise = np.random.randn(100) * 5

# %%
y_mod = y + noise

# %%
plt.scatter(x,y_mod)
